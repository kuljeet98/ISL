# %% [markdown]
# #### Frame Alteration

# %%
# importing libraries
import shutil
import cv2
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# to check the videos in the directory
video=[]
for i in os.listdir('/content/drive/My Drive/PROJECT_DATA/top_5_classes/saturday/'):
        video.append(i)

# %%
len(video)
# Out:
# 103

# %%
# function to convert the videos to frames
def evenframe(vp, ip):
    cap= cv2.VideoCapture(vp)
    i=1
    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret == False:
            break
        if i%2 == 0: # to pick even frames
            cv2.imwrite(ip+'IMG_'+str(i)+'.jpg',frame)
        i+=1
    cap.release()
    cv2.destroyAllWindows()
    return
def oddframe(video, folder):
    cap= cv2.VideoCapture(video)
    i=1
    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret == False:
            break
        if i%2 != 0: # to pick even frames
            cv2.imwrite(folder+'IMG_'+str(i)+'.jpg',frame)
        i+=1
    cap.release()
    cv2.destroyAllWindows()
    return

# %%
# to convert the frames to the videos 
for i in video:
    name = i.split(".")[0]
    # !mkdir 'ODD_'$name
    # !mkdir 'EVEN_'$name
    evenframe('/content/drive/My Drive/PROJECT_DATA/top_5_classes/saturday/'+i,"EVEN_"+name+"/")
    oddframe('/content/drive/My Drive/PROJECT_DATA/top_5_classes/saturday/'+i,"ODD_"+name+"/")
    new=[]
    for i in os.listdir("EVEN_"+name+"/"):
        new.append(i)
    length = len(new)//2
    odd= 0
    # !ffmpeg -framerate $length -pattern_type glob -i 'ODD_'$name'/*.jpg'\
     -c:v libx264  -pix_fmt yuv420p $name'_'$odd'.mp4'
    # !ffmpeg -framerate $length -pattern_type glob -i 'EVEN_'$name'/*.jpg'\
      -c:v libx264  -pix_fmt yuv420p $name'.mp4'
    try:
        shutil.rmtree('ODD_'+name)
        shutil.rmtree('EVEN_'+name)
        print("Directory Removed!!!")
    except:
        print("No directory Found!!!!")
# Out:
# Streaming output truncated to the last 5000 lines.
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   14 fps=0.0 q=-1.0 Lsize=     310kB time=00:00:01.57 bitrate=1615.4kbits/s speed=1.58x
# video:309kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.322784%
# [libx264 @ 0x559a5b79fe00] frame I:1     Avg QP:18.70  size:107862
# [libx264 @ 0x559a5b79fe00] frame P:4     Avg QP:20.71  size: 27274
# [libx264 @ 0x559a5b79fe00] frame B:9     Avg QP:22.17  size: 10963
# [libx264 @ 0x559a5b79fe00] consecutive B-frames: 14.3%  0.0%  0.0% 85.7%
# [libx264 @ 0x559a5b79fe00] mb I  I16..4:  1.1% 84.5% 14.4%
# [libx264 @ 0x559a5b79fe00] mb P  I16..4:  0.0%  0.5%  0.0%  P16..4: 57.7% 23.3% 14.5%  0.0%  0.0%    skip: 3.9%
# [libx264 @ 0x559a5b79fe00] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 54.8%  7.4%  1.4%  direct: 9.5%  skip:26.9%  L0:44.3% L1:42.9% BI:12.7%
# [libx264 @ 0x559a5b79fe00] 8x8 transform intra:84.5% inter:71.2%
# [libx264 @ 0x559a5b79fe00] coded y,uvDC,uvAC intra: 96.9% 78.4% 34.1% inter: 32.7% 60.2% 0.5%
# [libx264 @ 0x559a5b79fe00] i16 v,h,dc,p:  0% 59%  4% 37%
# [libx264 @ 0x559a5b79fe00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 39% 16%  4%  5%  4%  9%  5%  9%
# [libx264 @ 0x559a5b79fe00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 53%  6%  5%  6%  4%  8%  4%  6%
# [libx264 @ 0x559a5b79fe00] i8c dc,h,v,p: 40% 37% 18%  5%
# [libx264 @ 0x559a5b79fe00] Weighted P-Frames: Y:25.0% UV:25.0%
# [libx264 @ 0x559a5b79fe00] ref P L0: 71.6%  9.9% 10.9%  4.0%  3.6%
# [libx264 @ 0x559a5b79fe00] ref B L0: 81.9% 16.5%  1.6%
# [libx264 @ 0x559a5b79fe00] ref B L1: 90.9%  9.1%
# [libx264 @ 0x559a5b79fe00] kb/s:1262.49
# Directory Removed!!!
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'ODD_SATURDAY55/*.jpg':
#   Duration: 00:00:02.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55f9b28d2000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55f9b2427e00] using SAR=1/1
# [libx264 @ 0x55f9b2427e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55f9b2427e00] profile High, level 3.1
# [libx264 @ 0x55f9b2427e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=5 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY55_0.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   11 fps=0.0 q=-1.0 Lsize=     312kB time=00:00:01.60 bitrate=1597.2kbits/s speed=1.95x
# video:311kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.309278%
# [libx264 @ 0x55f9b2427e00] frame I:1     Avg QP:18.35  size:107161
# [libx264 @ 0x55f9b2427e00] frame P:3     Avg QP:19.86  size: 37660
# [libx264 @ 0x55f9b2427e00] frame B:7     Avg QP:21.09  size: 13951
# [libx264 @ 0x55f9b2427e00] consecutive B-frames:  9.1% 18.2%  0.0% 72.7%
# [libx264 @ 0x55f9b2427e00] mb I  I16..4:  2.0% 83.0% 15.0%
# [libx264 @ 0x55f9b2427e00] mb P  I16..4:  0.1%  2.6%  0.2%  P16..4: 60.8% 20.6% 13.8%  0.0%  0.0%    skip: 1.9%
# [libx264 @ 0x55f9b2427e00] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 50.9%  9.2%  2.1%  direct:10.9%  skip:26.8%  L0:34.4% L1:51.8% BI:13.8%
# [libx264 @ 0x55f9b2427e00] 8x8 transform intra:83.5% inter:66.6%
# [libx264 @ 0x55f9b2427e00] coded y,uvDC,uvAC intra: 97.3% 74.0% 26.5% inter: 37.7% 49.9% 1.0%
# [libx264 @ 0x55f9b2427e00] i16 v,h,dc,p:  0% 94%  0%  6%
# [libx264 @ 0x55f9b2427e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 40% 18%  4%  4%  3%  7%  4%  9%
# [libx264 @ 0x55f9b2427e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 45%  7%  5%  7%  6%  7%  5%  8%
# [libx264 @ 0x55f9b2427e00] i8c dc,h,v,p: 40% 39% 17%  5%
# [libx264 @ 0x55f9b2427e00] Weighted P-Frames: Y:33.3% UV:33.3%
# [libx264 @ 0x55f9b2427e00] ref P L0: 47.6%  9.8%  8.8% 33.8%
# [libx264 @ 0x55f9b2427e00] ref B L0: 86.2% 13.4%  0.3%
# [libx264 @ 0x55f9b2427e00] ref B L1: 97.4%  2.6%
# [libx264 @ 0x55f9b2427e00] kb/s:1155.62
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'EVEN_SATURDAY55/*.jpg':
#   Duration: 00:00:02.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55fcb9f74000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55fcb9ac9e00] using SAR=1/1
# [libx264 @ 0x55fcb9ac9e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55fcb9ac9e00] profile High, level 3.1
# [libx264 @ 0x55fcb9ac9e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=5 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY55.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   11 fps=0.0 q=-1.0 Lsize=     308kB time=00:00:01.60 bitrate=1577.0kbits/s speed=1.91x
# video:307kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.313251%
# [libx264 @ 0x55fcb9ac9e00] frame I:1     Avg QP:17.99  size:111902
# [libx264 @ 0x55fcb9ac9e00] frame P:3     Avg QP:19.82  size: 34190
# [libx264 @ 0x55fcb9ac9e00] frame B:7     Avg QP:21.04  size: 14183
# [libx264 @ 0x55fcb9ac9e00] consecutive B-frames:  9.1% 18.2%  0.0% 72.7%
# [libx264 @ 0x55fcb9ac9e00] mb I  I16..4:  1.7% 85.1% 13.2%
# [libx264 @ 0x55fcb9ac9e00] mb P  I16..4:  0.1%  1.7%  0.2%  P16..4: 55.1% 23.1% 16.4%  0.0%  0.0%    skip: 3.4%
# [libx264 @ 0x55fcb9ac9e00] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 51.2%  9.9%  1.9%  direct:11.3%  skip:25.5%  L0:45.0% L1:42.7% BI:12.2%
# [libx264 @ 0x55fcb9ac9e00] 8x8 transform intra:85.0% inter:64.1%
# [libx264 @ 0x55fcb9ac9e00] coded y,uvDC,uvAC intra: 98.0% 81.6% 34.5% inter: 37.9% 52.4% 0.9%
# [libx264 @ 0x55fcb9ac9e00] i16 v,h,dc,p:  0% 85%  4% 11%
# [libx264 @ 0x55fcb9ac9e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 37% 16%  4%  5%  4%  8%  5% 10%
# [libx264 @ 0x55fcb9ac9e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 54%  6%  4%  5%  4%  6%  4%  8%
# [libx264 @ 0x55fcb9ac9e00] i8c dc,h,v,p: 39% 38% 19%  5%
# [libx264 @ 0x55fcb9ac9e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55fcb9ac9e00] ref P L0: 55.1%  7.8% 14.5% 22.7%
# [libx264 @ 0x55fcb9ac9e00] ref B L0: 80.5% 18.3%  1.1%
# [libx264 @ 0x55fcb9ac9e00] ref B L1: 75.0% 25.0%
# [libx264 @ 0x55fcb9ac9e00] kb/s:1140.93
# Directory Removed!!!
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'ODD_SATURDAY56/*.jpg':
#   Duration: 00:00:02.17, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 6 fps, 6 tbr, 6 tbn, 6 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55cc2a3f4000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55cc29ed7e00] using SAR=1/1
# [libx264 @ 0x55cc29ed7e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55cc29ed7e00] profile High, level 3.1
# [libx264 @ 0x55cc29ed7e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY56_0.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 6 fps, 12288 tbn, 6 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   13 fps=0.0 q=-1.0 Lsize=     299kB time=00:00:01.66 bitrate=1469.7kbits/s speed=1.91x
# video:298kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.330620%
# [libx264 @ 0x55cc29ed7e00] frame I:1     Avg QP:18.47  size:103385
# [libx264 @ 0x55cc29ed7e00] frame P:3     Avg QP:20.14  size: 33080
# [libx264 @ 0x55cc29ed7e00] frame B:9     Avg QP:21.51  size: 11319
# [libx264 @ 0x55cc29ed7e00] consecutive B-frames:  7.7%  0.0%  0.0% 92.3%
# [libx264 @ 0x55cc29ed7e00] mb I  I16..4:  2.2% 82.4% 15.4%
# [libx264 @ 0x55cc29ed7e00] mb P  I16..4:  0.0%  1.8%  0.1%  P16..4: 54.8% 23.3% 16.0%  0.0%  0.0%    skip: 4.0%
# [libx264 @ 0x55cc29ed7e00] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 53.2%  7.5%  1.6%  direct: 6.4%  skip:31.3%  L0:39.4% L1:49.4% BI:11.2%
# [libx264 @ 0x55cc29ed7e00] 8x8 transform intra:83.1% inter:70.3%
# [libx264 @ 0x55cc29ed7e00] coded y,uvDC,uvAC intra: 96.8% 72.8% 24.7% inter: 33.1% 41.0% 0.8%
# [libx264 @ 0x55cc29ed7e00] i16 v,h,dc,p:  2% 88%  0% 10%
# [libx264 @ 0x55cc29ed7e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 40% 18%  4%  4%  3%  7%  4%  9%
# [libx264 @ 0x55cc29ed7e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 50%  7%  4%  6%  5%  7%  5%  6%
# [libx264 @ 0x55cc29ed7e00] i8c dc,h,v,p: 40% 39% 16%  5%
# [libx264 @ 0x55cc29ed7e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55cc29ed7e00] ref P L0: 57.7% 12.1% 21.4%  8.8%
# [libx264 @ 0x55cc29ed7e00] ref B L0: 79.8% 12.5%  7.6%
# [libx264 @ 0x55cc29ed7e00] ref B L1: 92.9%  7.1%
# [libx264 @ 0x55cc29ed7e00] kb/s:1124.29
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'EVEN_SATURDAY56/*.jpg':
#   Duration: 00:00:02.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 6 fps, 6 tbr, 6 tbn, 6 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55561ed62000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55561e883e00] using SAR=1/1
# [libx264 @ 0x55561e883e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55561e883e00] profile High, level 3.1
# [libx264 @ 0x55561e883e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY56.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 6 fps, 12288 tbn, 6 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   12 fps=0.0 q=-1.0 Lsize=     269kB time=00:00:01.50 bitrate=1467.5kbits/s speed=1.83x
# video:268kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.360712%
# [libx264 @ 0x55561e883e00] frame I:1     Avg QP:18.31  size:110924
# [libx264 @ 0x55561e883e00] frame P:3     Avg QP:20.31  size: 25920
# [libx264 @ 0x55561e883e00] frame B:8     Avg QP:21.55  size: 10601
# [libx264 @ 0x55561e883e00] consecutive B-frames:  8.3%  0.0% 25.0% 66.7%
# [libx264 @ 0x55561e883e00] mb I  I16..4:  1.0% 85.6% 13.4%
# [libx264 @ 0x55561e883e00] mb P  I16..4:  0.0%  0.6%  0.1%  P16..4: 56.0% 21.8% 16.1%  0.0%  0.0%    skip: 5.4%
# [libx264 @ 0x55561e883e00] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 51.2%  7.6%  1.4%  direct: 7.5%  skip:32.2%  L0:45.7% L1:39.9% BI:14.4%
# [libx264 @ 0x55561e883e00] 8x8 transform intra:85.4% inter:69.5%
# [libx264 @ 0x55561e883e00] coded y,uvDC,uvAC intra: 97.5% 80.2% 34.3% inter: 31.5% 42.1% 0.5%
# [libx264 @ 0x55561e883e00] i16 v,h,dc,p:  0% 88%  2% 10%
# [libx264 @ 0x55561e883e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 38% 16%  4%  5%  4%  8%  5%  9%
# [libx264 @ 0x55561e883e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7% 56%  6%  4%  5%  4%  7%  4%  6%
# [libx264 @ 0x55561e883e00] i8c dc,h,v,p: 39% 39% 18%  5%
# [libx264 @ 0x55561e883e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55561e883e00] ref P L0: 56.6% 10.9% 22.3% 10.2%
# [libx264 @ 0x55561e883e00] ref B L0: 79.5% 16.1%  4.4%
# [libx264 @ 0x55561e883e00] ref B L1: 93.0%  7.0%
# [libx264 @ 0x55561e883e00] kb/s:1093.97
# Directory Removed!!!
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'ODD_SATURDAY57/*.jpg':
#   Duration: 00:00:02.29, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 7 fps, 7 tbr, 7 tbn, 7 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55656ddf6000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55656d829e00] using SAR=1/1
# [libx264 @ 0x55656d829e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55656d829e00] profile High, level 3.1
# [libx264 @ 0x55656d829e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=7 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY57_0.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 7 fps, 14336 tbn, 7 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   16 fps= 15 q=-1.0 Lsize=     338kB time=00:00:01.85 bitrate=1490.3kbits/s speed=1.69x
# video:337kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.300628%
# [libx264 @ 0x55656d829e00] frame I:1     Avg QP:18.79  size: 95785
# [libx264 @ 0x55656d829e00] frame P:4     Avg QP:20.31  size: 32914
# [libx264 @ 0x55656d829e00] frame B:11    Avg QP:22.06  size: 10620
# [libx264 @ 0x55656d829e00] consecutive B-frames:  6.2%  0.0% 18.8% 75.0%
# [libx264 @ 0x55656d829e00] mb I  I16..4:  1.7% 84.1% 14.2%
# [libx264 @ 0x55656d829e00] mb P  I16..4:  0.0%  1.8%  0.2%  P16..4: 51.3% 24.6% 16.7%  0.0%  0.0%    skip: 5.4%
# [libx264 @ 0x55656d829e00] mb B  I16..4:  0.0%  0.1%  0.1%  B16..8: 52.9%  7.4%  1.7%  direct: 5.7%  skip:32.1%  L0:41.5% L1:48.2% BI:10.3%
# [libx264 @ 0x55656d829e00] 8x8 transform intra:84.1% inter:72.8%
# [libx264 @ 0x55656d829e00] coded y,uvDC,uvAC intra: 96.0% 71.2% 25.4% inter: 30.6% 40.5% 0.9%
# [libx264 @ 0x55656d829e00] i16 v,h,dc,p:  4% 85%  1% 10%
# [libx264 @ 0x55656d829e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 41% 18%  4%  4%  3%  7%  4%  8%
# [libx264 @ 0x55656d829e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 43%  7%  5%  6%  6%  8%  6%  7%
# [libx264 @ 0x55656d829e00] i8c dc,h,v,p: 41% 38% 17%  4%
# [libx264 @ 0x55656d829e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55656d829e00] ref P L0: 56.9% 15.4% 20.6%  7.1%
# [libx264 @ 0x55656d829e00] ref B L0: 79.5% 16.5%  4.1%
# [libx264 @ 0x55656d829e00] ref B L1: 92.3%  7.7%
# [libx264 @ 0x55656d829e00] kb/s:1204.90
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'EVEN_SATURDAY57/*.jpg':
#   Duration: 00:00:02.14, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 7 fps, 7 tbr, 7 tbn, 7 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55928c338000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55928bda9e00] using SAR=1/1
# [libx264 @ 0x55928bda9e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55928bda9e00] profile High, level 3.1
# [libx264 @ 0x55928bda9e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=7 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY57.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 7 fps, 14336 tbn, 7 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   15 fps= 14 q=-1.0 Lsize=     315kB time=00:00:01.71 bitrate=1506.7kbits/s speed= 1.6x
# video:314kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.320954%
# [libx264 @ 0x55928bda9e00] frame I:1     Avg QP:18.60  size:102252
# [libx264 @ 0x55928bda9e00] frame P:4     Avg QP:20.37  size: 27530
# [libx264 @ 0x55928bda9e00] frame B:10    Avg QP:22.08  size: 10880
# [libx264 @ 0x55928bda9e00] consecutive B-frames:  6.7% 13.3%  0.0% 80.0%
# [libx264 @ 0x55928bda9e00] mb I  I16..4:  1.1% 84.0% 14.9%
# [libx264 @ 0x55928bda9e00] mb P  I16..4:  0.0%  0.9%  0.1%  P16..4: 52.7% 23.5% 15.0%  0.0%  0.0%    skip: 7.8%
# [libx264 @ 0x55928bda9e00] mb B  I16..4:  0.0%  0.1%  0.1%  B16..8: 52.9%  7.3%  1.5%  direct: 7.0%  skip:31.1%  L0:49.3% L1:40.7% BI:10.0%
# [libx264 @ 0x55928bda9e00] 8x8 transform intra:83.5% inter:71.3%
# [libx264 @ 0x55928bda9e00] coded y,uvDC,uvAC intra: 96.8% 81.0% 38.9% inter: 30.5% 42.6% 0.6%
# [libx264 @ 0x55928bda9e00] i16 v,h,dc,p:  4% 65%  2% 29%
# [libx264 @ 0x55928bda9e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 38% 16%  4%  5%  4%  9%  5%  9%
# [libx264 @ 0x55928bda9e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 56%  6%  4%  6%  4%  7%  4%  6%
# [libx264 @ 0x55928bda9e00] i8c dc,h,v,p: 39% 39% 16%  5%
# [libx264 @ 0x55928bda9e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55928bda9e00] ref P L0: 57.1% 12.4% 19.2% 11.3%
# [libx264 @ 0x55928bda9e00] ref B L0: 83.8% 14.6%  1.6%
# [libx264 @ 0x55928bda9e00] ref B L1: 93.3%  6.7%
# [libx264 @ 0x55928bda9e00] kb/s:1199.02
# Directory Removed!!!
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'ODD_SATURDAY58/*.jpg':
#   Duration: 00:00:02.18, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 11 fps, 11 tbr, 11 tbn, 11 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5645513c8000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x564550db9e00] using SAR=1/1
# [libx264 @ 0x564550db9e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x564550db9e00] profile High, level 3.1
# [libx264 @ 0x564550db9e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=11 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY58_0.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 11 fps, 11264 tbn, 11 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   24 fps= 15 q=-1.0 Lsize=     333kB time=00:00:01.90 bitrate=1427.9kbits/s speed=1.21x
# video:332kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.333594%
# [libx264 @ 0x564550db9e00] frame I:1     Avg QP:20.02  size: 51373
# [libx264 @ 0x564550db9e00] frame P:6     Avg QP:20.16  size: 22866
# [libx264 @ 0x564550db9e00] frame B:17    Avg QP:21.41  size:  8846
# [libx264 @ 0x564550db9e00] consecutive B-frames:  4.2%  0.0% 12.5% 83.3%
# [libx264 @ 0x564550db9e00] mb I  I16..4:  8.2% 81.6% 10.2%
# [libx264 @ 0x564550db9e00] mb P  I16..4:  2.1%  9.9%  1.2%  P16..4: 53.0% 16.8%  9.0%  0.0%  0.0%    skip: 8.0%
# [libx264 @ 0x564550db9e00] mb B  I16..4:  0.4%  1.0%  0.1%  B16..8: 49.3%  6.4%  1.2%  direct: 6.1%  skip:35.5%  L0:44.3% L1:49.2% BI: 6.5%
# [libx264 @ 0x564550db9e00] 8x8 transform intra:76.9% inter:79.0%
# [libx264 @ 0x564550db9e00] coded y,uvDC,uvAC intra: 68.8% 43.3% 6.6% inter: 23.8% 31.9% 0.0%
# [libx264 @ 0x564550db9e00] i16 v,h,dc,p: 15% 21% 16% 48%
# [libx264 @ 0x564550db9e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 23% 31%  4%  4%  4%  6%  4%  7%
# [libx264 @ 0x564550db9e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 20% 13%  7%  8%  9%  9%  7%  8%
# [libx264 @ 0x564550db9e00] i8c dc,h,v,p: 61% 19% 16%  4%
# [libx264 @ 0x564550db9e00] Weighted P-Frames: Y:16.7% UV:0.0%
# [libx264 @ 0x564550db9e00] ref P L0: 48.7% 12.6% 21.3% 15.4%  2.0%
# [libx264 @ 0x564550db9e00] ref B L0: 79.8% 16.1%  4.1%
# [libx264 @ 0x564550db9e00] ref B L1: 93.5%  6.5%
# [libx264 @ 0x564550db9e00] kb/s:1242.80
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'EVEN_SATURDAY58/*.jpg':
#   Duration: 00:00:02.09, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 11 fps, 11 tbr, 11 tbn, 11 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5629773fa000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x562976e1de00] using SAR=1/1
# [libx264 @ 0x562976e1de00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x562976e1de00] profile High, level 3.1
# [libx264 @ 0x562976e1de00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=11 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY58.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 11 fps, 11264 tbn, 11 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   23 fps= 15 q=-1.0 Lsize=     305kB time=00:00:01.81 bitrate=1373.4kbits/s speed=1.19x
# video:304kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.362986%
# [libx264 @ 0x562976e1de00] frame I:1     Avg QP:19.42  size: 48450
# [libx264 @ 0x562976e1de00] frame P:6     Avg QP:20.32  size: 19934
# [libx264 @ 0x562976e1de00] frame B:16    Avg QP:21.50  size:  8893
# [libx264 @ 0x562976e1de00] consecutive B-frames:  4.3%  8.7%  0.0% 87.0%
# [libx264 @ 0x562976e1de00] mb I  I16..4:  9.8% 78.6% 11.6%
# [libx264 @ 0x562976e1de00] mb P  I16..4:  2.5%  8.6%  0.9%  P16..4: 58.1% 14.8%  8.3%  0.0%  0.0%    skip: 6.8%
# [libx264 @ 0x562976e1de00] mb B  I16..4:  0.3%  0.8%  0.2%  B16..8: 48.3%  6.4%  1.1%  direct: 6.5%  skip:36.4%  L0:47.0% L1:47.8% BI: 5.1%
# [libx264 @ 0x562976e1de00] 8x8 transform intra:74.3% inter:79.6%
# [libx264 @ 0x562976e1de00] coded y,uvDC,uvAC intra: 66.6% 43.5% 6.9% inter: 24.4% 32.0% 0.0%
# [libx264 @ 0x562976e1de00] i16 v,h,dc,p: 14% 20% 16% 50%
# [libx264 @ 0x562976e1de00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 21% 29%  5%  5%  4%  6%  5%  7%
# [libx264 @ 0x562976e1de00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 21% 13%  6%  8%  9%  8%  6%  7%
# [libx264 @ 0x562976e1de00] i8c dc,h,v,p: 59% 20% 17%  4%
# [libx264 @ 0x562976e1de00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x562976e1de00] ref P L0: 41.0%  5.3% 24.3% 29.4%
# [libx264 @ 0x562976e1de00] ref B L0: 77.8% 15.8%  6.3%
# [libx264 @ 0x562976e1de00] ref B L1: 89.1% 10.9%
# [libx264 @ 0x562976e1de00] kb/s:1187.40
# Directory Removed!!!
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'ODD_SATURDAY59/*.jpg':
#   Duration: 00:00:02.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5601ce8d4000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5601ce341e00] using SAR=1/1
# [libx264 @ 0x5601ce341e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5601ce341e00] profile High, level 3.1
# [libx264 @ 0x5601ce341e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY59_0.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   21 fps= 15 q=-1.0 Lsize=     276kB time=00:00:01.80 bitrate=1256.8kbits/s speed=1.27x
# video:275kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.392288%
# [libx264 @ 0x5601ce341e00] frame I:1     Avg QP:18.89  size: 53992
# [libx264 @ 0x5601ce341e00] frame P:5     Avg QP:19.61  size: 22150
# [libx264 @ 0x5601ce341e00] frame B:15    Avg QP:20.95  size:  7750
# [libx264 @ 0x5601ce341e00] consecutive B-frames:  4.8%  0.0%  0.0% 95.2%
# [libx264 @ 0x5601ce341e00] mb I  I16..4:  8.1% 80.9% 10.9%
# [libx264 @ 0x5601ce341e00] mb P  I16..4:  1.8%  8.7%  0.4%  P16..4: 54.0% 19.0%  9.6%  0.0%  0.0%    skip: 6.4%
# [libx264 @ 0x5601ce341e00] mb B  I16..4:  0.2%  0.6%  0.0%  B16..8: 48.1%  4.9%  0.9%  direct: 7.7%  skip:37.5%  L0:43.5% L1:51.3% BI: 5.2%
# [libx264 @ 0x5601ce341e00] 8x8 transform intra:79.7% inter:77.4%
# [libx264 @ 0x5601ce341e00] coded y,uvDC,uvAC intra: 69.0% 39.0% 5.2% inter: 24.6% 32.8% 0.0%
# [libx264 @ 0x5601ce341e00] i16 v,h,dc,p: 12% 18% 21% 49%
# [libx264 @ 0x5601ce341e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 24% 33%  4%  4%  3%  5%  4%  6%
# [libx264 @ 0x5601ce341e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 22% 13%  6%  7%  6% 10%  7%  8%
# [libx264 @ 0x5601ce341e00] i8c dc,h,v,p: 61% 18% 17%  4%
# [libx264 @ 0x5601ce341e00] Weighted P-Frames: Y:20.0% UV:20.0%
# [libx264 @ 0x5601ce341e00] ref P L0: 51.7% 17.8% 19.8% 10.6%
# [libx264 @ 0x5601ce341e00] ref B L0: 82.2% 15.6%  2.2%
# [libx264 @ 0x5601ce341e00] ref B L1: 92.6%  7.4%
# [libx264 @ 0x5601ce341e00] kb/s:1070.45
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'EVEN_SATURDAY59/*.jpg':
#   Duration: 00:00:02.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x557253090000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x557252b25e00] using SAR=1/1
# [libx264 @ 0x557252b25e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x557252b25e00] profile High, level 3.1
# [libx264 @ 0x557252b25e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY59.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
# ...
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   18 fps= 16 q=-1.0 Lsize=     266kB time=00:00:01.87 bitrate=1164.0kbits/s speed=1.63x
# video:265kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.393357%
# [libx264 @ 0x55f145c89e00] frame I:1     Avg QP:17.05  size: 62166
# [libx264 @ 0x55f145c89e00] frame P:5     Avg QP:18.59  size: 21062
# [libx264 @ 0x55f145c89e00] frame B:12    Avg QP:19.39  size:  8633
# [libx264 @ 0x55f145c89e00] consecutive B-frames: 11.1%  0.0%  0.0% 88.9%
# [libx264 @ 0x55f145c89e00] mb I  I16..4: 24.2% 66.8%  8.9%
# [libx264 @ 0x55f145c89e00] mb P  I16..4:  3.8% 10.3%  0.2%  P16..4: 38.2% 13.1% 11.2%  0.0%  0.0%    skip:23.2%
# [libx264 @ 0x55f145c89e00] mb B  I16..4:  1.6%  3.7%  0.0%  B16..8: 42.0%  6.7%  1.4%  direct: 7.9%  skip:36.8%  L0:39.9% L1:51.9% BI: 8.2%
# [libx264 @ 0x55f145c89e00] 8x8 transform intra:69.2% inter:74.9%
# [libx264 @ 0x55f145c89e00] coded y,uvDC,uvAC intra: 42.5% 22.6% 7.0% inter: 22.7% 21.0% 0.7%
# [libx264 @ 0x55f145c89e00] i16 v,h,dc,p: 24% 31% 20% 25%
# [libx264 @ 0x55f145c89e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 20% 46%  2%  2%  3%  2%  2%  2%
# [libx264 @ 0x55f145c89e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 14% 13%  5%  9% 10%  9%  8%  6%
# [libx264 @ 0x55f145c89e00] i8c dc,h,v,p: 77% 10% 10%  3%
# [libx264 @ 0x55f145c89e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55f145c89e00] ref P L0: 57.1%  7.0% 22.2% 13.7%
# [libx264 @ 0x55f145c89e00] ref B L0: 72.6% 23.7%  3.7%
# [libx264 @ 0x55f145c89e00] ref B L1: 89.5% 10.5%
# [libx264 @ 0x55f145c89e00] kb/s:963.82
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'EVEN_SATURDAY102/*.jpg':
#   Duration: 00:00:02.13, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 8 fps, 8 tbr, 8 tbn, 8 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55dcfb8f2000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55dcfb431e00] using SAR=1/1
# [libx264 @ 0x55dcfb431e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55dcfb431e00] profile High, level 3.1
# [libx264 @ 0x55dcfb431e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=8 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY102.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 8 fps, 16384 tbn, 8 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   17 fps= 15 q=-1.0 Lsize=     245kB time=00:00:01.75 bitrate=1148.0kbits/s speed=1.58x
# video:244kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.422665%
# [libx264 @ 0x55dcfb431e00] frame I:1     Avg QP:17.71  size: 64018
# [libx264 @ 0x55dcfb431e00] frame P:4     Avg QP:18.54  size: 21686
# [libx264 @ 0x55dcfb431e00] frame B:12    Avg QP:19.34  size:  8219
# [libx264 @ 0x55dcfb431e00] consecutive B-frames:  5.9%  0.0%  0.0% 94.1%
# [libx264 @ 0x55dcfb431e00] mb I  I16..4: 26.9% 64.3%  8.7%
# [libx264 @ 0x55dcfb431e00] mb P  I16..4:  3.8% 10.7%  0.2%  P16..4: 41.2% 13.8% 11.3%  0.0%  0.0%    skip:19.0%
# [libx264 @ 0x55dcfb431e00] mb B  I16..4:  1.8%  3.9%  0.0%  B16..8: 42.6%  6.7%  1.2%  direct: 7.3%  skip:36.6%  L0:45.3% L1:45.9% BI: 8.8%
# [libx264 @ 0x55dcfb431e00] 8x8 transform intra:67.7% inter:76.3%
# [libx264 @ 0x55dcfb431e00] coded y,uvDC,uvAC intra: 45.3% 21.6% 8.5% inter: 22.2% 20.4% 0.5%
# [libx264 @ 0x55dcfb431e00] i16 v,h,dc,p: 22% 32% 23% 24%
# [libx264 @ 0x55dcfb431e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 19% 47%  2%  3%  3%  3%  3%  3%
# [libx264 @ 0x55dcfb431e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 17% 16%  5%  9%  8%  7%  7%  6%
# [libx264 @ 0x55dcfb431e00] i8c dc,h,v,p: 77% 10% 10%  2%
# [libx264 @ 0x55dcfb431e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55dcfb431e00] ref P L0: 54.3%  6.4% 25.5% 13.8%
# [libx264 @ 0x55dcfb431e00] ref B L0: 79.6% 14.6%  5.8%
# [libx264 @ 0x55dcfb431e00] ref B L1: 88.6% 11.4%
# [libx264 @ 0x55dcfb431e00] kb/s:938.89
# Directory Removed!!!
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'ODD_SATURDAY103/*.jpg':
#   Duration: 00:00:02.07, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 14 fps, 14 tbr, 14 tbn, 14 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x558992bde000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x558992567e00] using SAR=1/1
# [libx264 @ 0x558992567e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x558992567e00] profile High, level 3.1
# [libx264 @ 0x558992567e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=14 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY103_0.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 14 fps, 14336 tbn, 14 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   29 fps= 18 q=-1.0 Lsize=     248kB time=00:00:01.85 bitrate=1094.0kbits/s speed=1.12x
# video:247kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.475113%
# [libx264 @ 0x558992567e00] frame I:1     Avg QP:18.58  size: 49012
# [libx264 @ 0x558992567e00] frame P:7     Avg QP:20.00  size: 15222
# [libx264 @ 0x558992567e00] frame B:21    Avg QP:21.17  size:  4597
# [libx264 @ 0x558992567e00] consecutive B-frames:  3.4%  0.0%  0.0% 96.6%
# [libx264 @ 0x558992567e00] mb I  I16..4: 30.1% 61.3%  8.6%
# [libx264 @ 0x558992567e00] mb P  I16..4:  4.9%  6.1%  0.1%  P16..4: 39.4% 10.8%  9.5%  0.0%  0.0%    skip:29.2%
# [libx264 @ 0x558992567e00] mb B  I16..4:  0.8%  1.0%  0.0%  B16..8: 42.1%  3.8%  0.6%  direct: 2.1%  skip:49.5%  L0:44.7% L1:51.4% BI: 3.9%
# [libx264 @ 0x558992567e00] 8x8 transform intra:58.0% inter:84.5%
# [libx264 @ 0x558992567e00] coded y,uvDC,uvAC intra: 28.1% 19.5% 6.6% inter: 12.9% 13.2% 0.3%
# [libx264 @ 0x558992567e00] i16 v,h,dc,p: 24% 37% 16% 23%
# [libx264 @ 0x558992567e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 19% 46%  2%  3%  3%  3%  3%  2%
# [libx264 @ 0x558992567e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 15% 11%  6%  9% 10% 10% 10%  8%
# [libx264 @ 0x558992567e00] i8c dc,h,v,p: 79% 10%  9%  2%
# [libx264 @ 0x558992567e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x558992567e00] ref P L0: 48.0%  8.8% 34.7%  8.5%
# [libx264 @ 0x558992567e00] ref B L0: 71.2% 20.4%  8.4%
# [libx264 @ 0x558992567e00] ref B L1: 87.1% 12.9%
# [libx264 @ 0x558992567e00] kb/s:973.60
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'EVEN_SATURDAY103/*.jpg':
#   Duration: 00:00:02.07, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 14 fps, 14 tbr, 14 tbn, 14 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x558f6654a000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x558f65ecbe00] using SAR=1/1
# [libx264 @ 0x558f65ecbe00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x558f65ecbe00] profile High, level 3.1
# [libx264 @ 0x558f65ecbe00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=14 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'SATURDAY103.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 14 fps, 14336 tbn, 14 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   29 fps= 19 q=-1.0 Lsize=     240kB time=00:00:01.85 bitrate=1056.9kbits/s speed=1.19x
# video:238kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.491903%
# [libx264 @ 0x558f65ecbe00] frame I:1     Avg QP:19.51  size: 49580
# [libx264 @ 0x558f65ecbe00] frame P:7     Avg QP:20.00  size: 14773
# [libx264 @ 0x558f65ecbe00] frame B:21    Avg QP:21.24  size:  4308
# [libx264 @ 0x558f65ecbe00] consecutive B-frames:  3.4%  0.0%  0.0% 96.6%
# [libx264 @ 0x558f65ecbe00] mb I  I16..4: 32.5% 60.5%  7.0%
# [libx264 @ 0x558f65ecbe00] mb P  I16..4:  5.9%  7.8%  0.1%  P16..4: 37.6% 12.0%  8.7%  0.0%  0.0%    skip:28.0%
# [libx264 @ 0x558f65ecbe00] mb B  I16..4:  0.6%  0.9%  0.0%  B16..8: 40.8%  3.5%  0.4%  direct: 1.7%  skip:52.1%  L0:47.1% L1:49.4% BI: 3.6%
# [libx264 @ 0x558f65ecbe00] 8x8 transform intra:58.7% inter:83.3%
# [libx264 @ 0x558f65ecbe00] coded y,uvDC,uvAC intra: 28.2% 18.8% 6.9% inter: 12.8% 11.9% 0.3%
# [libx264 @ 0x558f65ecbe00] i16 v,h,dc,p: 28% 33% 17% 23%
# [libx264 @ 0x558f65ecbe00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 18% 47%  2%  3%  3%  4%  3%  3%
# [libx264 @ 0x558f65ecbe00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 16% 16%  5%  8%  8%  7%  8%  5%
# [libx264 @ 0x558f65ecbe00] i8c dc,h,v,p: 80%  9%  9%  2%
# [libx264 @ 0x558f65ecbe00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x558f65ecbe00] ref P L0: 46.5%  8.5% 29.2% 15.7%
# [libx264 @ 0x558f65ecbe00] ref B L0: 76.3% 18.7%  5.0%
# [libx264 @ 0x558f65ecbe00] ref B L1: 88.6% 11.4%
# [libx264 @ 0x558f65ecbe00] kb/s:940.28
# Directory Removed!!!

# %%
destdir = "/content/drive/My Drive/Frames/saturday/"
conv=[]
for file in os.listdir('/content/'):
  if file.endswith(".mp4"):
    conv.append(file)
'''video path from / content to drive'''
import shutil
for i in conv:   
  shutil.move(i, destdir+i)
print('Done...')
# Out:
# Done...

# %%
import os
import sys
# sourcedir='/content/drive/My Drive/PROJECT_DATA/top_5_classes/monday/'
# files = os.listdir('/content/drive/My Drive/Frames/wednesday/')
j=0
path = '/content/drive/My Drive/Frames/saturday/'
files = os.listdir(path)
for file in files:
    os.rename(os.path.join(path, file), os.path.join(path, 'SATURDAY' + str(j) + '.mp4'))
    j+=1
